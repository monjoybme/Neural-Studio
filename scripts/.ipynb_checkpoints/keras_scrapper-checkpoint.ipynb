# %%
import re

from selenium.webdriver import Chrome
from json import load,dump

# %%
bot = Chrome()

# %%
base_url = 'https://keras.io/api/layers'

# %%
bot.get(base_url)

# %%
groups = [ group.text.lower().replace("-","").replace(" ","-") for group in bot.find_elements_by_tag_name("h3")[5:]]

# %%
elem = None

config = {}

for group in groups:
    bot.get(base_url)
    elem = bot.find_element_by_id(group)
    elem.find_element_by_tag_name("a").click()
    
    group_url = bot.current_url
    group_name = bot.find_element_by_id(group).text
    
    layer_urls = [ (a.text,a.get_property("href")) for a in bot.find_element_by_tag_name("ul").find_elements_by_tag_name("a")]
    group_layers = []
    for name,url in layer_urls:
        bot.get(url)
        layer_name = re.sub("( layer)|( object)|( layers)","",name)
        code = bot.find_element_by_tag_name("pre")
        args = dict([
            i.strip()
            .replace("\"","")
            .replace(",","")
            .split("=") if "=" in i else (i.strip().replace("\"","").replace(",",""),"REQUIRED")
            for i in 
            code.text.split("\n")[1:-1]
            if 'kwargs' not in i
        ])
        group_layers.append(dict(
            name=layer_name,
            args=args,
            doc=url
        ))
        
    config[group] = dict(
        name=group_name,
        layers=group_layers,
        doc=group_url
    )

# %%
with open("../data/layer_config.json","w+") as file:
    dump(config,file)

# %%
with open("../data/layer_config.json","r") as file:
    config = load(file)

# %%
args = {}

for lg in config.values():
    for ll in lg['layers']:
        for arg,val in ll['args'].items():
            if arg in args:
                args[arg].append((ll['name'],val))
            else:
                args[arg] = []
                args[arg].append((ll['name'],val))

# %%
{
 'shape':{
     "default":None,
     "type":"tuple",
     "render":"text"
 },    
 'batch_size': {
     "default":None,
     "type":"number",
     "render":"text"
 },
 'name': {
     "default":None,
     "type":"text",
     "render":"text"
 },
 'dtype': {
     "default":None,
     "type":"text",
     "render":"text"
 },
 'sparse': {
     "default":False,
     "type":"bool",
     "render":"list"
 },
 'tensor': {
     "default":None,
     "type":None,
     "render":False
 },
 'ragged': {
     "default":False,
     "type":"bool",
     "render":"list"
 },
 'units': [('Dense', 'REQUIRED'),
           ('LSTM', 'REQUIRED'),
           ('GRU', 'REQUIRED'),
           ('SimpleRNN', 'REQUIRED')],
 'activation': [('Dense', 'None'),
                ('Conv1D', 'None'),
                ('Conv2D', 'None'),
                ('Conv3D', 'None'),
                ('SeparableConv1D', 'None'),
                ('SeparableConv2D', 'None'),
                ('DepthwiseConv2D', 'None'),
                ('Conv2DTranspose', 'None'),
                ('Conv3DTranspose', 'None'),
                ('LSTM', 'tanh'),
                ('GRU', 'tanh'),
                ('SimpleRNN', 'tanh'),
                ('ConvLSTM2D', 'tanh'),
                ('LocallyConnected1D', 'None'),
                ('LocallyConnected2D', 'None')],
 'use_bias': [('Dense', 'True'),
              ('Conv1D', 'True'),
              ('Conv2D', 'True'),
              ('Conv3D', 'True'),
              ('SeparableConv1D', 'True'),
              ('SeparableConv2D', 'True'),
              ('DepthwiseConv2D', 'True'),
              ('Conv2DTranspose', 'True'),
              ('Conv3DTranspose', 'True'),
              ('LSTM', 'True'),
              ('GRU', 'True'),
              ('SimpleRNN', 'True'),
              ('ConvLSTM2D', 'True'),
              ('MultiHeadAttention', 'True'),
              ('LocallyConnected1D', 'True'),
              ('LocallyConnected2D', 'True')],
 'kernel_initializer': [('Dense', 'glorot_uniform'),
                        ('Conv1D', 'glorot_uniform'),
                        ('Conv2D', 'glorot_uniform'),
                        ('Conv3D', 'glorot_uniform'),
                        ('Conv2DTranspose', 'glorot_uniform'),
                        ('Conv3DTranspose', 'glorot_uniform'),
                        ('LSTM', 'glorot_uniform'),
                        ('GRU', 'glorot_uniform'),
                        ('SimpleRNN', 'glorot_uniform'),
                        ('ConvLSTM2D', 'glorot_uniform'),
                        ('MultiHeadAttention', 'glorot_uniform'),
                        ('LocallyConnected1D', 'glorot_uniform'),
                        ('LocallyConnected2D', 'glorot_uniform')],
 'bias_initializer': [('Dense', 'zeros'),
                      ('Conv1D', 'zeros'),
                      ('Conv2D', 'zeros'),
                      ('Conv3D', 'zeros'),
                      ('SeparableConv1D', 'zeros'),
                      ('SeparableConv2D', 'zeros'),
                      ('DepthwiseConv2D', 'zeros'),
                      ('Conv2DTranspose', 'zeros'),
                      ('Conv3DTranspose', 'zeros'),
                      ('LSTM', 'zeros'),
                      ('GRU', 'zeros'),
                      ('SimpleRNN', 'zeros'),
                      ('ConvLSTM2D', 'zeros'),
                      ('MultiHeadAttention', 'zeros'),
                      ('LocallyConnected1D', 'zeros'),
                      ('LocallyConnected2D', 'zeros')],
 'kernel_regularizer': [('Dense', 'None'),
                        ('Conv1D', 'None'),
                        ('Conv2D', 'None'),
                        ('Conv3D', 'None'),
                        ('Conv2DTranspose', 'None'),
                        ('Conv3DTranspose', 'None'),
                        ('LSTM', 'None'),
                        ('GRU', 'None'),
                        ('SimpleRNN', 'None'),
                        ('ConvLSTM2D', 'None'),
                        ('MultiHeadAttention', 'None'),
                        ('LocallyConnected1D', 'None'),
                        ('LocallyConnected2D', 'None')],
 'bias_regularizer': [('Dense', 'None'),
                      ('Conv1D', 'None'),
                      ('Conv2D', 'None'),
                      ('Conv3D', 'None'),
                      ('SeparableConv1D', 'None'),
                      ('SeparableConv2D', 'None'),
                      ('DepthwiseConv2D', 'None'),
                      ('Conv2DTranspose', 'None'),
                      ('Conv3DTranspose', 'None'),
                      ('LSTM', 'None'),
                      ('GRU', 'None'),
                      ('SimpleRNN', 'None'),
                      ('ConvLSTM2D', 'None'),
                      ('MultiHeadAttention', 'None'),
                      ('LocallyConnected1D', 'None'),
                      ('LocallyConnected2D', 'None')],
 'activity_regularizer': [('Dense', 'None'),
                          ('Embedding', 'None'),
                          ('Conv1D', 'None'),
                          ('Conv2D', 'None'),
                          ('Conv3D', 'None'),
                          ('SeparableConv1D', 'None'),
                          ('SeparableConv2D', 'None'),
                          ('DepthwiseConv2D', 'None'),
                          ('Conv2DTranspose', 'None'),
                          ('Conv3DTranspose', 'None'),
                          ('LSTM', 'None'),
                          ('GRU', 'None'),
                          ('SimpleRNN', 'None'),
                          ('ConvLSTM2D', 'None'),
                          ('MultiHeadAttention', 'None'),
                          ('LocallyConnected1D', 'None'),
                          ('LocallyConnected2D', 'None')],
 'kernel_constraint': [('Dense', 'None'),
                       ('Conv1D', 'None'),
                       ('Conv2D', 'None'),
                       ('Conv3D', 'None'),
                       ('Conv2DTranspose', 'None'),
                       ('Conv3DTranspose', 'None'),
                       ('LSTM', 'None'),
                       ('GRU', 'None'),
                       ('SimpleRNN', 'None'),
                       ('ConvLSTM2D', 'None'),
                       ('MultiHeadAttention', 'None'),
                       ('LocallyConnected1D', 'None'),
                       ('LocallyConnected2D', 'None')],
 'bias_constraint': [('Dense', 'None'),
                     ('Conv1D', 'None'),
                     ('Conv2D', 'None'),
                     ('Conv3D', 'None'),
                     ('SeparableConv1D', 'None'),
                     ('SeparableConv2D', 'None'),
                     ('DepthwiseConv2D', 'None'),
                     ('Conv2DTranspose', 'None'),
                     ('Conv3DTranspose', 'None'),
                     ('LSTM', 'None'),
                     ('GRU', 'None'),
                     ('SimpleRNN', 'None'),
                     ('ConvLSTM2D', 'None'),
                     ('MultiHeadAttention', 'None'),
                     ('LocallyConnected1D', 'None'),
                     ('LocallyConnected2D', 'None')],
 'input_dim': [('Embedding', 'REQUIRED')],
 'output_dim': [('Embedding', 'REQUIRED')],
 'embeddings_initializer': [('Embedding', 'uniform')],
 'embeddings_regularizer': [('Embedding', 'None')],
 'embeddings_constraint': [('Embedding', 'None')],
 'mask_zero': [('Embedding', 'False')],
 'input_length': [('Embedding', 'None')],
 'filters': [('Conv1D', 'REQUIRED'),
             ('Conv2D', 'REQUIRED'),
             ('Conv3D', 'REQUIRED'),
             ('SeparableConv1D', 'REQUIRED'),
             ('SeparableConv2D', 'REQUIRED'),
             ('Conv2DTranspose', 'REQUIRED'),
             ('Conv3DTranspose', 'REQUIRED'),
             ('ConvLSTM2D', 'REQUIRED'),
             ('LocallyConnected1D', 'REQUIRED'),
             ('LocallyConnected2D', 'REQUIRED')],
 'kernel_size': [('Conv1D', 'REQUIRED'),
                 ('Conv2D', 'REQUIRED'),
                 ('Conv3D', 'REQUIRED'),
                 ('SeparableConv1D', 'REQUIRED'),
                 ('SeparableConv2D', 'REQUIRED'),
                 ('DepthwiseConv2D', 'REQUIRED'),
                 ('Conv2DTranspose', 'REQUIRED'),
                 ('Conv3DTranspose', 'REQUIRED'),
                 ('ConvLSTM2D', 'REQUIRED'),
                 ('LocallyConnected1D', 'REQUIRED'),
                 ('LocallyConnected2D', 'REQUIRED')],
 'strides': [('Conv1D', '1'),
             ('Conv2D', '(1 1)'),
             ('Conv3D', '(1 1 1)'),
             ('SeparableConv1D', '1'),
             ('SeparableConv2D', '(1 1)'),
             ('DepthwiseConv2D', '(1 1)'),
             ('Conv2DTranspose', '(1 1)'),
             ('Conv3DTranspose', '(1 1 1)'),
             ('ConvLSTM2D', '(1 1)'),
             ('LocallyConnected1D', '1'),
             ('LocallyConnected2D', '(1 1)')],
 'padding': [('Conv1D', 'valid'),
             ('Conv2D', 'valid'),
             ('Conv3D', 'valid'),
             ('SeparableConv1D', 'valid'),
             ('SeparableConv2D', 'valid'),
             ('DepthwiseConv2D', 'valid'),
             ('Conv2DTranspose', 'valid'),
             ('Conv3DTranspose', 'valid'),
             ('ConvLSTM2D', 'valid'),
             ('LocallyConnected1D', 'valid'),
             ('LocallyConnected2D', 'valid')],
 'data_format': [('Conv1D', 'channels_last'),
                 ('Conv2D', 'None'),
                 ('Conv3D', 'None'),
                 ('SeparableConv1D', 'None'),
                 ('SeparableConv2D', 'None'),
                 ('DepthwiseConv2D', 'None'),
                 ('Conv2DTranspose', 'None'),
                 ('Conv3DTranspose', 'None'),
                 ('ConvLSTM2D', 'None'),
                 ('LocallyConnected1D', 'None'),
                 ('LocallyConnected2D', 'None')],
 'dilation_rate': [('Conv1D', '1'),
                   ('Conv2D', '(1 1)'),
                   ('Conv3D', '(1 1 1)'),
                   ('SeparableConv1D', '1'),
                   ('SeparableConv2D', '(1 1)'),
                   ('DepthwiseConv2D', '(1 1)'),
                   ('Conv2DTranspose', '(1 1)'),
                   ('Conv3DTranspose', '(1 1 1)'),
                   ('ConvLSTM2D', '(1 1)')],
 'groups': [('Conv1D', '1'), ('Conv2D', '1'), ('Conv3D', '1')],
 'depth_multiplier': [('SeparableConv1D', '1'),
                      ('SeparableConv2D', '1'),
                      ('DepthwiseConv2D', '1')],
 'depthwise_initializer': [('SeparableConv1D', 'glorot_uniform'),
                           ('SeparableConv2D', 'glorot_uniform'),
                           ('DepthwiseConv2D', 'glorot_uniform')],
 'pointwise_initializer': [('SeparableConv1D', 'glorot_uniform'),
                           ('SeparableConv2D', 'glorot_uniform')],
 'depthwise_regularizer': [('SeparableConv1D', 'None'),
                           ('SeparableConv2D', 'None'),
                           ('DepthwiseConv2D', 'None')],
 'pointwise_regularizer': [('SeparableConv1D', 'None'),
                           ('SeparableConv2D', 'None')],
 'depthwise_constraint': [('SeparableConv1D', 'None'),
                          ('SeparableConv2D', 'None'),
                          ('DepthwiseConv2D', 'None')],
 'pointwise_constraint': [('SeparableConv1D', 'None'),
                          ('SeparableConv2D', 'None')],
 'output_padding': [('Conv2DTranspose', 'None'), ('Conv3DTranspose', 'None')],
 'recurrent_activation': [('LSTM', 'sigmoid'),
                          ('GRU', 'sigmoid'),
                          ('ConvLSTM2D', 'hard_sigmoid')],
 'recurrent_initializer': [('LSTM', 'orthogonal'),
                           ('GRU', 'orthogonal'),
                           ('SimpleRNN', 'orthogonal'),
                           ('ConvLSTM2D', 'orthogonal')],
 'unit_forget_bias': [('LSTM', 'True'), ('ConvLSTM2D', 'True')],
 'recurrent_regularizer': [('LSTM', 'None'),
                           ('GRU', 'None'),
                           ('SimpleRNN', 'None'),
                           ('ConvLSTM2D', 'None')],
 'recurrent_constraint': [('LSTM', 'None'),
                          ('GRU', 'None'),
                          ('SimpleRNN', 'None'),
                          ('ConvLSTM2D', 'None')],
 'dropout': [('LSTM', '0.0'),
             ('GRU', '0.0'),
             ('SimpleRNN', '0.0'),
             ('ConvLSTM2D', '0.0'),
             ('MultiHeadAttention', '0.0')],
 'recurrent_dropout': [('LSTM', '0.0'),
                       ('GRU', '0.0'),
                       ('SimpleRNN', '0.0'),
                       ('ConvLSTM2D', '0.0')],
 'return_sequences': [('LSTM', 'False'),
                      ('GRU', 'False'),
                      ('SimpleRNN', 'False'),
                      ('ConvLSTM2D', 'False'),
                      ('Base RNN', 'False')],
 'return_state': [('LSTM', 'False'),
                  ('GRU', 'False'),
                  ('SimpleRNN', 'False'),
                  ('ConvLSTM2D', 'False'),
                  ('Base RNN', 'False')],
 'go_backwards': [('LSTM', 'False'),
                  ('GRU', 'False'),
                  ('SimpleRNN', 'False'),
                  ('ConvLSTM2D', 'False'),
                  ('Base RNN', 'False')],
 'stateful': [('LSTM', 'False'),
              ('GRU', 'False'),
              ('SimpleRNN', 'False'),
              ('ConvLSTM2D', 'False'),
              ('Base RNN', 'False')],
 'time_major': [('LSTM', 'False'), ('GRU', 'False'), ('Base RNN', 'False')],
 'unroll': [('LSTM', 'False'),
            ('GRU', 'False'),
            ('SimpleRNN', 'False'),
            ('Base RNN', 'False')],
 'reset_after': [('GRU', 'True')],
 'cell': [('Base RNN', 'REQUIRED')],
 'max_tokens': [('TextVectorization', 'None')],
 'standardize': [('TextVectorization', 'lower_and_strip_punctuation')],
 'split': [('TextVectorization', 'whitespace')],
 'ngrams': [('TextVectorization', 'None')],
 'output_mode': [('TextVectorization', 'int')],
 'output_sequence_length': [('TextVectorization', 'None')],
 'pad_to_max_tokens': [('TextVectorization', 'True')],
 'vocabulary': [('TextVectorization', 'None')],
 'axis': [('BatchNormalization', '-1'), ('LayerNormalization', '-1')],
 'momentum': [('BatchNormalization', '0.99')],
 'epsilon': [('BatchNormalization', '0.001'), ('LayerNormalization', '0.001')],
 'center': [('BatchNormalization', 'True'), ('LayerNormalization', 'True')],
 'scale': [('BatchNormalization', 'True'), ('LayerNormalization', 'True')],
 'beta_initializer': [('BatchNormalization', 'zeros'),
                      ('LayerNormalization', 'zeros')],
 'gamma_initializer': [('BatchNormalization', 'ones'),
                       ('LayerNormalization', 'ones')],
 'moving_mean_initializer': [('BatchNormalization', 'zeros')],
 'moving_variance_initializer': [('BatchNormalization', 'ones')],
 'beta_regularizer': [('BatchNormalization', 'None'),
                      ('LayerNormalization', 'None')],
 'gamma_regularizer': [('BatchNormalization', 'None'),
                       ('LayerNormalization', 'None')],
 'beta_constraint': [('BatchNormalization', 'None'),
                     ('LayerNormalization', 'None')],
 'gamma_constraint': [('BatchNormalization', 'None'),
                      ('LayerNormalization', 'None')],
 'renorm': [('BatchNormalization', 'False')],
 'renorm_clipping': [('BatchNormalization', 'None')],
 'renorm_momentum': [('BatchNormalization', '0.99')],
 'fused': [('BatchNormalization', 'None')],
 'trainable': [('BatchNormalization', 'True'), ('LayerNormalization', 'True')],
 'virtual_batch_size': [('BatchNormalization', 'None')],
 'adjustment': [('BatchNormalization', 'None')],
 'num_heads': [('MultiHeadAttention', 'REQUIRED')],
 'key_dim': [('MultiHeadAttention', 'REQUIRED')],
 'value_dim': [('MultiHeadAttention', 'None')],
 'output_shape': [('MultiHeadAttention', 'None')],
 'attention_axes': [('MultiHeadAttention', 'None')],
 'implementation': [('LocallyConnected1D', '1'), ('LocallyConnected2D', '1')],
 'alpha_initializer': [('PReLU', 'zeros')],
 'alpha_regularizer': [('PReLU', 'None')],
 'alpha_constraint': [('PReLU', 'None')],
 'shared_axes': [('PReLU', 'None')]}
# Out:
# 92
