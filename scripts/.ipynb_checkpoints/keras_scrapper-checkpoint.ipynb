# %% [markdown]
# ### Layers

# %%
import re
from requests import get

from selenium.webdriver import Chrome
from json import load,dump

# %%
bot = Chrome()

# %%
base_url = 'https://keras.io/api/layers'

# %%
bot.get(base_url)

# %%
groups = [ group.text.lower().replace("-","").replace(" ","-") for group in bot.find_elements_by_tag_name("h3")[5:]]

# %%
elem = None
layers = {}
REQUIRED = 'required'

def get_render_list(arg,val)->str:
    if val.istitle():
        val = eval(val)
    if type(val) == bool:
        return "bool"
    return arg.split("_")[-1]

def get_render_type(arg,val:str)->str:
    if val.istitle():
        val = eval(val)
        
    if type(val) == bool:
        return "list"
    elif type(val) == str or val == None:
        if arg.split("_")[-1] in ['activation','initializer','regularizer','constraint']:
            return "list"
        return 'text'
    else:
        return "text"

def get_args(code:str)->dict:
    args = [ 
        a0[:-1].split("=") 
            if 
        a0 
            else 
        (a1[:-1],"REQUIRED") 
        for a0,a1 in  re.findall("(\w+=[a-zA-Z0-9\(\), ]+)|(\w+,)",code) 
    ]

    return {
        arg:{
            "value":val.__str__(),
            "type":re.sub("([<>''])|(class )","",str(type(val))),
            "render":get_render_type(arg,val),
            "options":get_render_list(arg,val)
        }
        for arg,val in args
    }

for group in groups:
    bot.get(base_url)
    elem = bot.find_element_by_id(group)
    elem.find_element_by_tag_name("a").click()
    
    group_url = bot.current_url
    group_name = bot.find_element_by_id(group).text
    
    layer_urls = [ (a.text,a.get_property("href")) for a in bot.find_element_by_tag_name("ul").find_elements_by_tag_name("a")]
    group_layers = []
    for name,url in layer_urls:
        bot.get(url)
        layer_name = re.sub("( layer)|( object)|( layers)","",name)
        code = bot.find_element_by_tag_name("pre")
        group_layers.append(dict(
            name=layer_name,
            args=get_args(code.text),
            doc=url
        ))
        
    layers[group] = dict(
        name=group_name,
        layers=group_layers,
        doc=group_url
    )
# Out:
# shape None
# batch_size None
# name None
# dtype None
# sparse False
# tensor None
# ragged False
# units REQUIRED
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# activation REQUIRED
# input_dim REQUIRED
# output_dim REQUIRED
# embeddings_regularizer None
# activity_regularizer None
# embeddings_constraint None
# mask_zero False
# input_length None
# mask_value
# 0 REQUIRED
# function REQUIRED
# output_shape None, mas
# None REQUIRED
# arguments None,
# filters REQUIRED
# kernel_size REQUIRED
# strides 1
# dilation_rate 1
# groups 1
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1)
# data_format None
# dilation_rate (1, 1)
# groups 1
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1, 1)
# data_format None
# dilation_rate (1, 1, 1)
# groups 1
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# filters REQUIRED
# kernel_size REQUIRED
# strides 1
# data_format None
# dilation_rate 1
# depth_multiplier 1
# activation None
# use_bias True
# depthwise_regularizer None
# pointwise_regularizer None
# bias_regularizer None
# activity_regularizer None
# depthwise_constraint None
# pointwise_constraint None
# bias_constraint None
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1)
# data_format None
# dilation_rate (1, 1)
# depth_multiplier 1
# activation None
# use_bias True
# depthwise_regularizer None
# pointwise_regularizer None
# bias_regularizer None
# activity_regularizer None
# depthwise_constraint None
# pointwise_constraint None
# bias_constraint None
# kernel_size REQUIRED
# strides (1, 1)
# depth_multiplier 1
# data_format None
# dilation_rate (1, 1)
# activation None
# use_bias True
# depthwise_regularizer None
# bias_regularizer None
# activity_regularizer None
# depthwise_constraint None
# bias_constraint None
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1)
# output_padding None
# data_format None
# dilation_rate (1, 1)
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1, 1)
# output_padding None
# data_format None
# dilation_rate (1, 1, 1)
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# pool_size 2, stride
# None REQUIRED
# pool_size (2, 2), stride
# None REQUIRED
# data_format None,
# pool_size (2, 2, 2), stride
# None REQUIRED
# data_format None,
# pool_size 2, stride
# None REQUIRED
# pool_size (2, 2), stride
# None REQUIRED
# data_format None,
# pool_size (2, 2, 2), stride
# None REQUIRED
# data_format None,
# data_format None,
# data_format None,
# data_format None,
# data_format None,
# units REQUIRED
# use_bias True
# unit_forget_bias True
# kernel_regularizer None
# recurrent_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# recurrent_constraint None
# bias_constraint None
# dropout
# 0 REQUIRED
# recurrent_dropout
# 0 REQUIRED
# return_sequences False
# return_state False
# go_backwards False
# stateful False
# time_major False
# unroll False
# units REQUIRED
# use_bias True
# kernel_regularizer None
# recurrent_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# recurrent_constraint None
# bias_constraint None
# dropout
# 0 REQUIRED
# recurrent_dropout
# 0 REQUIRED
# return_sequences False
# return_state False
# go_backwards False
# stateful False
# unroll False
# time_major False
# reset_after True
# units REQUIRED
# use_bias True
# kernel_regularizer None
# recurrent_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# recurrent_constraint None
# bias_constraint None
# dropout
# 0 REQUIRED
# recurrent_dropout
# 0 REQUIRED
# return_sequences False
# return_state False
# go_backwards False
# stateful False
# unroll False
# layer REQUIRED
# layer REQUIRED
# weights None, backwar
# _layer None,
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1)
# data_format None
# dilation_rate (1, 1)
# use_bias True
# unit_forget_bias True
# kernel_regularizer None
# recurrent_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# recurrent_constraint None
# bias_constraint None
# return_sequences False
# return_state False
# go_backwards False
# stateful False
# dropout
# 0 REQUIRED
# recurrent_dropout
# 0 REQUIRED
# cell REQUIRED
# return_sequences False
# return_state False
# go_backwards False
# stateful False
# unroll False
# time_major False
# max_tokens None
# ngrams None
# output_sequence_length None
# pad_to_max_tokens True
# vocabulary None
# 1 REQUIRED
# dtype None, mea
# None REQUIRED
# variance None,
# 1 REQUIRED
# momentum
# 99 REQUIRED
# epsilon
# 001 REQUIRED
# center True
# scale True
# beta_regularizer None
# gamma_regularizer None
# beta_constraint None
# gamma_constraint None
# renorm False
# renorm_clipping None
# renorm_momentum
# 99 REQUIRED
# fused None
# trainable True
# virtual_batch_size None
# adjustment None
# name None
# 1 REQUIRED
# epsilon
# 001 REQUIRED
# center True
# scale True
# beta_regularizer None
# gamma_regularizer None
# beta_constraint None
# gamma_constraint None
# trainable True
# name None
# rate REQUIRED
# noise_shape None, see
# None REQUIRED
# rate REQUIRED
# rate REQUIRED
# data_format None,
# rate REQUIRED
# data_format None,
# rate REQUIRED
# stddev REQUIRED
# l1
# 0 REQUIRED
# l2
# 0 REQUIRED
# rate REQUIRED
# noise_shape None, see
# None REQUIRED
# num_heads REQUIRED
# key_dim REQUIRED
# value_dim None
# dropout
# 0 REQUIRED
# use_bias True
# output_shape None
# attention_axes None
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# use_scale False,
# use_scale True,
# target_shape REQUIRED
# data_format None,
# n REQUIRED
# dims REQUIRED
# cropping (1, 1),
# cropping ((0, 0), (0, 0)), dat
# _format None,
# cropping ((1, 1), (1, 1), (1, 1)), dat
# _format None,
# size 2,
# size (2, 2), dat
# _format None, interpolatio
# size (2, 2, 2), dat
# _format None,
# padding 1,
# padding (1, 1), dat
# _format None,
# padding (1, 1, 1), dat
# _format None,
# 1 REQUIRED
# axes REQUIRED
# normalize False,
# filters REQUIRED
# kernel_size REQUIRED
# strides 1
# data_format None
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# implementation 1
# filters REQUIRED
# kernel_size REQUIRED
# strides (1, 1)
# data_format None
# activation None
# use_bias True
# kernel_regularizer None
# bias_regularizer None
# activity_regularizer None
# kernel_constraint None
# bias_constraint None
# implementation 1
# max_value None, negativ
# _slope 0, threshol
# 0 REQUIRED
# 1 REQUIRED
# alpha
# 3 REQUIRED
# alpha_regularizer None
# alpha_constraint None
# shared_axes None
# alpha
# 0 REQUIRED
# theta
# 0 REQUIRED

# %%
with open("../html/src/data/layers.js","w+") as file:
    file.write(f"""
const layers = {layers.__repr__()}

export default layers;
""")

# %% [markdown]
# ### Callbacks

# %%
code="""tf.keras.layers.DepthwiseConv2D(
    kernel_size,
    strides=(1, 1),
    padding="valid",
    depth_multiplier=1,
    data_format=None,
    dilation_rate=(1, 1),
    activation=None,
    use_bias=True,
    depthwise_initializer="glorot_uniform",
    bias_initializer="zeros",
    depthwise_regularizer=None,
    bias_regularizer=None,
    activity_regularizer=None,
    depthwise_constraint=None,
    bias_constraint=None,
    **kwargs
)"""

# %%
re.findall("(\w+=[a-zA-Z0-9\(\), ]+)|(\w+,)",code)
# Out:
# [('', 'kernel_size,'),
#  ('strides=(1, 1),', ''),
#  ('depth_multiplier=1,', ''),
#  ('data_format=None,', ''),
#  ('dilation_rate=(1, 1),', ''),
#  ('activation=None,', ''),
#  ('use_bias=True,', ''),
#  ('depthwise_regularizer=None,', ''),
#  ('bias_regularizer=None,', ''),
#  ('activity_regularizer=None,', ''),
#  ('depthwise_constraint=None,', ''),
#  ('bias_constraint=None,', '')]

# %%
import re
from requests import get

# %%
callback_urls = re.findall("""/api/callbacks/\w+""",get("https://keras.io/api/callbacks/").text)
config = {}

for url in callback_urls:
    args = re.findall(
            """tf.keras.callbacks.\w+\([a-zA-Z0-9 \t\n,;:="\n_\*]+""",
            re.sub("""(<[a-zA-Z-=0-9\" ,./!:?@;&+\']*>)|(</[a-zA-Z=0-9\" ]*>)|(\n)|(&quot;)""",'',get(f"https://keras.io{url}").text)
        )
    args = args[0] if len(args) else None
    cls, args = args.split("(") if args else ( None,None )
    
    if cls:
        config[cls.split(".")[-1]] = dict([ arg.strip().split("=") if "=" in arg else (arg.strip().replace(",",''),"REQUIRED") for arg in args.split(", ") if 'kwargs' not in arg])
        
config
# Out:
# {'ModelCheckpoint': {'filepath': 'REQUIRED',
#   'monitor': 'val_loss',
#   'verbose': '0',
#   'save_best_only': 'False',
#   'save_weights_only': 'False',
#   'mode': 'auto',
#   'save_freq': 'epoch',
#   'options': 'None'},
#  'TensorBoard': {'log_dir': 'logs',
#   'histogram_freq': '0',
#   'write_graph': 'True',
#   'write_images': 'False',
#   'update_freq': 'epoch',
#   'profile_batch': '2',
#   'embeddings_freq': '0',
#   'embeddings_metadata': 'None'},
#  'EarlyStopping': {'monitor': 'val_loss',
#   'min_delta': '0',
#   'patience': '0',
#   'verbose': '0',
#   'mode': 'auto',
#   'baseline': 'None',
#   'restore_best_weights': 'False,'},
#  'LearningRateScheduler': {'schedule': 'REQUIRED', 'verbose': '0'},
#  'ReduceLROnPlateau': {'monitor': 'val_loss', 'factor': '0'},
#  'RemoteMonitor': {'root': 'http:'},
#  'LambdaCallback': {'on_epoch_begin': 'None',
#   'on_epoch_end': 'None',
#   'on_batch_begin': 'None',
#   'on_batch_end': 'None',
#   'on_train_begin': 'None',
#   'on_train_end': 'None'},
#  'CSVLogger': {'filename': 'REQUIRED', 'separator': ',', 'append': 'False'},
#  'ProgbarLogger': {'count_mode': 'samples', 'stateful_metrics': 'None'}}

# %%
with open("../html/src/data/callbacks.js","w+") as file:
    file.write(f"""
const callbacks = {config.__repr__()}

export default callbacks;
""")

# %% [markdown]
# ### Optmizers

# %%
urls = re.findall("""/api/optimizers/\w+""",get("https://keras.io/api/optimizers/").text)
config = {}

for url in urls:
    args = re.findall(
            """tf.keras.optimizers.\w+\([a-zA-Z0-9 \t\n,;:="\n_\*\.-]+""",
            re.sub("""(<[a-zA-Z-=0-9\" ,./!:?@;&+\']*>)|(</[a-zA-Z=0-9\" ]*>)|(\n)|(&quot;)""",'',get(f"https://keras.io{url}").text)
        )
    args = args[0] if len(args) else None
    callback, args = args.split("(") if args else ( None,None )
    
    if callback:
        config[callback.split(".")[-1]] = dict([ arg.strip().split("=") if "=" in arg else (arg.strip().replace(",",''),"REQUIRED") for arg in args.split(", ") if 'kwargs' not in arg])

config
# Out:
# {'SGD': {'learning_rate': '0.01',
#   'momentum': '0.0',
#   'nesterov': 'False',
#   'name': 'SGD'},
#  'RMSprop': {'learning_rate': '0.001',
#   'rho': '0.9',
#   'momentum': '0.0',
#   'epsilon': '1e-07',
#   'centered': 'False',
#   'name': 'RMSprop'},
#  'Adam': {'learning_rate': '0.001',
#   'beta_1': '0.9',
#   'beta_2': '0.999',
#   'epsilon': '1e-07',
#   'amsgrad': 'False',
#   'name': 'Adam'},
#  'Adadelta': {'learning_rate': '0.001',
#   'rho': '0.95',
#   'epsilon': '1e-07',
#   'name': 'Adadelta'},
#  'Adagrad': {'learning_rate': '0.001',
#   'initial_accumulator_value': '0.1',
#   'epsilon': '1e-07',
#   'name': 'Adagrad'},
#  'Adamax': {'learning_rate': '0.001',
#   'beta_1': '0.9',
#   'beta_2': '0.999',
#   'epsilon': '1e-07',
#   'name': 'Adamax'},
#  'Nadam': {'learning_rate': '0.001',
#   'beta_1': '0.9',
#   'beta_2': '0.999',
#   'epsilon': '1e-07',
#   'name': 'Nadam'},
#  'Ftrl': {'learning_rate': '0.001',
#   'learning_rate_power': '-0.5',
#   'initial_accumulator_value': '0.1',
#   'l1_regularization_strength': '0.0',
#   'l2_regularization_strength': '0.0',
#   'name': 'Ftrl',
#   'l2_shrinkage_regularization_strength': '0.0',
#   'beta': '0.0'}}

# %%
with open("../html/src/data/optimizers.js","w+") as file:
    file.write(f"""
const optimizers = {config.__repr__()}

export default optimizers;
""")

# %% [markdown]
# ### Layers

# %%
from tensorflow import keras
import inspect

# %%
urls = list(set(re.findall("""/api/layers/\w+/\w+""",get("https://keras.io/api/layers/").text)))

# %%
layer_groups = {}

for url in urls:
    _,_,_,group,layer = url.split("/")
    layer_groups[layer.replace("_","")] = group

# %%
layers = { i:{ "name":i.replace("_"," ").title(), "layers":[] } for i in set(layer_groups.values()) }
parameters = []

def get_render_list(arg,val)->str:
    if type(val) == bool:
        return "bool"
    return arg.split("_")[-1]

def get_render_type(arg,val)->str:
    if type(val) == bool:
        return "list"
    elif type(val) == str:
        if arg.split("_")[-1] in ['activation','initializer','regularizer','constraint']:
            return "list"
        return 'text'
    else:
        return "text"

for layer in dir(keras.layers):
    if layer[0].isupper():
        spec = eval(f"inspect.getfullargspec (keras.layers.{layer}.__init__)")
        defaults = list(spec.defaults) if spec.defaults else []
        args = spec.args[1:]
        
        pad = len(spec.args) - len(defaults)
        vals =  (["REQUIRED"]*pad) + defaults
        
        if layer.lower() in layer_groups:
            layers[layer_groups[layer.lower()]]['layers'].append({
                "name":layer,
                "type":layer,
                "arguments":{ 
                    arg:{
                            "value":val.__str__(),
                            "type":re.sub("([<>''])|(class )","",str(type(val))),
                            "render":get_render_type(arg,val),
                            "options":get_render_list(arg,val)
                        }
                        for arg,val in zip(args,vals) 
                    }
                }
            )
            parameters += args

# %%
# with open("../html/src/data/layers.js","w+") as file:
#     file.write(f"""
# const layers = {layers.__repr__()}

# export default layers;
# """)

# %% [markdown]
# ### Options

# %%
options = dict(
    activation = [
        'None',
        'elu',
        'exponential',
        'gelu',
        'get',
        'hard_sigmoid',
        'linear',
        'relu',
        'selu',
        'serialize',
        'sigmoid',
        'softmax',
        'softplus',
        'softsign',
        'swish',
        'tanh'
    ],

    constraint = [
        'None',
        'max_norm',
        'min_max_norm',
        'non_neg',
        'radial_constraint',
        'serialize',
        'unit_norm'
    ],

    regularizer = [
        'None',
        'l1',
        'l1_l2',
        'l2',
    ],

    initializer = [
        'None',
        'glorot_normal',
        'glorot_uniform',
        'he_normal',
        'he_uniform',
        'identity',
        'lecun_normal',
        'lecun_uniform',
        'ones',
        'orthogonal',
        'random_normal',
        'random_uniform',
        'serialize',
        'truncated_normal',
        'variance_scaling',
        'zeros'
    ],

    metrics = [
        'None',
        'binary_accuracy',
        'binary_crossentropy',
        'categorical_accuracy',
        'categorical_crossentropy',
        'deserialize',
        'get',
        'hinge',
        'kl_divergence',
        'kld',
        'kullback_leibler_divergence',
        'log_cosh',
        'logcosh',
        'mae',
        'mape',
        'mean_absolute_error',
        'mean_absolute_percentage_error',
        'mean_squared_error',
        'mean_squared_logarithmic_error',
        'mse',
        'msle',
        'poisson',
        'serialize',
        'sparse_categorical_accuracy',
        'sparse_categorical_crossentropy',
        'sparse_top_k_categorical_accuracy',
        'squared_hinge',
        'top_k_categorical_accuracy'
    ],

    loss = [
        'None',
        'binary_crossentropy',
        'categorical_crossentropy',
        'categorical_hinge',
        'cosine_similarity',
        'deserialize',
        'get',
        'hinge',
        'huber',
        'kl_divergence',
        'kld',
        'kullback_leibler_divergence',
        'log_cosh',
        'logcosh',
        'mae',
        'mape',
        'mean_absolute_error',
        'mean_absolute_percentage_error',
        'mean_squared_error',
        'mean_squared_logarithmic_error',
        'mse',
        'msle',
        'poisson',
        'serialize',
        'sparse_categorical_crossentropy',
        'squared_hinge'
    ],

    optimizer = [
        'None',
        'adadelta',
        'adagrad',
        'adam',
        'adamax',
        'ftrl',
        'nadam',
        'optimizer',
        'rmsprop',
        'sgd'
    ]
)

# %%
with open("../html/src/data/options.js","w+") as file:
    file.write(f"""
const options = {options.__repr__()}

export default options;
""")
